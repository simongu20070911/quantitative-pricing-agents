# %%
import databento as db
key12= "DnFD9dK4Dsji7GDQXGp8736gi3AA6"
client = db.Historical("db-")

data = client.timeseries.get_range(
    dataset='GLBX.MDP3',       # CME Globex Data
    symbols=['ES.c.0'],        # <--- The Smart Symbol
    stype_in='continuous',     # <--- MANDATORY: Tells DB to use smart logic
    schema='ohlcv-1m',         # Your 1-minute bars
    start='2010-06-06',
    end='2025-11-18'
)

df = data.to_df()
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# BentoClientError                          Traceback (most recent call last)
# Cell In[7], line 5
#       2 key12= "DnFD9dK4Dsji7GDQXGp8736gi3AA6"
#       3 client = db.Historical("db-")
# ----> 5 data = client.timeseries.get_range(
#       6     dataset='GLBX.MDP3',       # CME Globex Data
#       7     symbols=['ES.c.0'],        # <--- The Smart Symbol
#       8     stype_in='continuous',     # <--- MANDATORY: Tells DB to use smart logic
#       9     schema='ohlcv-1m',         # Your 1-minute bars
#      10     start='2010-06-06',
#      11     end='2025-11-18'
#      12 )
#      14 df = data.to_df()
#      15 print(df.head())
#
# File ~/Documents/Library_QPA/python_tools/.venv/lib/python3.11/site-packages/databento/historical/api/timeseries.py:125, in TimeseriesHttpAPI.get_range(self, dataset, start, end, symbols, schema, stype_in, stype_out, limit, path)
#     122 if path is not None:
#     123     path = validate_file_write_path(path, "path")
# --> 125 return self._stream(
#     126     url=self._base_url + ".get_range",
#     127     data=data,
#     128     basic_auth=True,
#     129     path=path,
#     130 )
#
# File ~/Documents/Library_QPA/python_tools/.venv/lib/python3.11/site-packages/databento/common/http.py:134, in BentoHttpAPI._stream(self, url, data, basic_auth, path)
#     125 with requests.post(
#     126     url=url,
#     127     data=data,
#    (...)    131     stream=True,
#     132 ) as response:
#     133     check_backend_warnings(response)
# --> 134     check_http_error(response)
#     136     if path is None:
#     137         writer: IO[bytes] = BytesIO()
#
# File ~/Documents/Library_QPA/python_tools/.venv/lib/python3.11/site-packages/databento/common/http.py:249, in check_http_error(response)
#     247 if response.status_code == 408:
#     248     message = "The request transmission timed out."
# --> 249 raise BentoClientError(
#     250     http_status=response.status_code,
#     251     http_body=response.content,
#     252     json_body=json_body,
#     253     message=message,
#     254     headers=response.headers,
#     255 )
#
# BentoClientError: 401 auth_authentication_failed
# Authentication failed.
# documentation: https://databento.com/docs/portal/api-keys

# %%
df.reset_index(inplace=True)

# 3. NOW when you save or print, ts_event is there
#save to csv
df.to_csv("es.c.0-20100606-20251116.ohlcv-1m.csv", index=False)

# %%
import databento as db

client = db.Historical("YOUR_API_KEY")

# Check size BEFORE downloading
bytes_count = client.timeseries.get_billable_size(
    dataset='GLBX.MDP3',
    symbols=['ES.c.0'],        # Your Smart Symbol
    stype_in='continuous',     # Smart Logic
    schema='ohlcv-1m',         # 1-minute bars
    start='2010-01-01',
    end='2020-01-01'
)

# Convert to Gigabytes (GB)
gb_count = bytes_count / (1024 * 1024 * 1024)

# Databento Historical CME data is usually around $25 - $30 per GB
estimated_cost = gb_count * 30 

print(f"Size: {gb_count:.4f} GB")
print(f"Estimated Cost: ${estimated_cost:.2f}")

# %% [markdown]
# ****data_transforms**

# %%
#read the csv 
import pandas as pd
df=pd.read_csv("es.c.0-20100606-20251116.ohlcv-1m.csv")
df.head()
# Out:
#                     ts_event  rtype  publisher_id  instrument_id     open  \
# 0  2010-06-07 00:00:00+00:00     33             1           6640  1061.25
# 1  2010-06-07 00:01:00+00:00     33             1           6640  1061.25
# 2  2010-06-07 00:02:00+00:00     33             1           6640  1061.75
# 3  2010-06-07 00:03:00+00:00     33             1           6640  1061.50
# 4  2010-06-07 00:04:00+00:00     33             1           6640  1061.25
#
#       high      low    close  volume  symbol
# 0  1061.75  1061.25  1061.25     206  ES.c.0
# 1  1062.00  1061.25  1062.00     495  ES.c.0
# 2  1062.00  1061.50  1061.50     476  ES.c.0
# 3  1061.50  1061.00  1061.00     270  ES.c.0
# 4  1062.25  1061.00  1062.25     349  ES.c.0

# %%
df['ts_event'] = pd.to_datetime(df['ts_event'])

# 3. Convert directly to Eastern Time
# No need to localize, just convert.
df['ET_datetime'] = df['ts_event'].dt.tz_convert('America/New_York')

# 4. Verify
print(df[['ts_event', 'ET_datetime']].head())
# Out:
#                    ts_event               ET_datetime
# 0 2010-06-07 00:00:00+00:00 2010-06-06 20:00:00-04:00
# 1 2010-06-07 00:01:00+00:00 2010-06-06 20:01:00-04:00
# 2 2010-06-07 00:02:00+00:00 2010-06-06 20:02:00-04:00
# 3 2010-06-07 00:03:00+00:00 2010-06-06 20:03:00-04:00
# 4 2010-06-07 00:04:00+00:00 2010-06-06 20:04:00-04:00

# %%
#save the csv
df.to_csv("es.c.0-20100606-20251116.et.ohlcv-1m.csv", index=False)
